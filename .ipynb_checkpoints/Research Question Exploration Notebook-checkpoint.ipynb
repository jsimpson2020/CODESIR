# %% [markdown]
# # This notebook is for exploring research questions

# %% [markdown]
# ### Importing packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import scipy as sp
import pandas as pd
import Model_Functions as mf

# %% [markdown]
# ### Basic SIR model
#
# Call function mf.BrauerSIR()
#
# Possible inputs: (Default values shown)
#
#     initial_population=100000
#     length_of_infection=20
#     avg_contacts_per_day=0.25
#     total_time=365
#     initial_percent_recovered=0.0
#     initial_percent_infected=1.0
#     plot=False
#     parameters=False
#
# The plot variable turns on and off the plot output. The parameters variable turns on and off a print message with the parameters. See Kermack-McKendrick SIR Model (Brauer 2008) notebook for further explanation.

# %%
mf.BrauerSIR(plot=True)
# Out:
#          days   susceptible     infected     recovered          total
# 0        0.00  99000.000000  1000.000000      0.000000  100000.000000
# 1        0.01  98997.525000  1001.975000      0.500000  100000.000000
# 2        0.02  98995.045174  1003.953839      1.000987  100000.000000
# 3        0.03  98992.560512  1005.936523      1.502964  100000.000000
# 4        0.04  98990.071007  1007.923061      2.005933  100000.000000
# ...       ...           ...          ...           ...            ...
# 36495  364.95    689.168568     0.000000  99309.832073   99999.000641
# 36496  364.96    689.168568     0.000000  99309.832073   99999.000641
# 36497  364.97    689.168568     0.000000  99309.832073   99999.000641
# 36498  364.98    689.168568     0.000000  99309.832073   99999.000641
# 36499  364.99    689.168568     0.000000  99309.832073   99999.000641
#
# [36500 rows x 5 columns]

# %% [markdown]
# ### Basic SEIR model
#
# Possible inputs: (Default values shown)
#
#     initial_population=100000
#     length_of_infection=20
#     length_of_exposure=5
#     avg_contacts_per_day=0.25
#     total_time=365
#     initial_percent_recovered=0.0
#     initial_percent_infected=1.0
#     initial_percent_exposed=0.0
#     plot=False
#     parameters=False
#
# The plot variable turns on and off the plot output. The parameters variable turns on and off a print message with the parameters. See Brauer 2008 SEIR model notebook for further explanation.

# %%
mf.BrauerSEIR(plot=True)
# Out:
#          days   susceptible       exposed     infected     recovered  \
# 0        0.00  99000.000000  0.000000e+00  1000.000000      0.000000
# 1        0.01  98997.525000  2.475000e+00   999.500000      0.500000
# 2        0.02  98995.051299  4.943751e+00   999.005200      0.999750
# 3        0.03  98992.578885  7.406277e+00   998.515585      1.499253
# 4        0.04  98990.107744  9.862606e+00   998.031140      1.998510
# ...       ...           ...           ...          ...           ...
# 36495  364.95    689.440046  2.252646e-09     0.000000  99309.549188
# 36496  364.96    689.440046  2.248141e-09     0.000000  99309.549188
# 36497  364.97    689.440046  2.243645e-09     0.000000  99309.549188
# 36498  364.98    689.440046  2.239157e-09     0.000000  99309.549188
# 36499  364.99    689.440046  2.234679e-09     0.000000  99309.549188
#
#                total
# 0      100000.000000
# 1      100000.000000
# 2      100000.000000
# 3      100000.000000
# 4      100000.000000
# ...              ...
# 36495   99998.989234
# 36496   99998.989234
# 36497   99998.989234
# 36498   99998.989234
# 36499   99998.989234
#
# [36500 rows x 6 columns]

# %% [markdown]
# ### Basic SIS model
#
# Possible inputs: (Default values shown)
#
#     initial_population=100000
#     length_of_infection=20
#     avg_contacts_per_day=0.25
#     total_time=365
#     initial_percent_recovered=0.0
#     initial_percent_infected=1.0
#     fraction_recovered=1
#     plot=False
#     parameters=False
#
# The plot variable turns on and off the plot output. The parameters variable turns on and off a print message with the parameters. See Brauer 2008 SIS notebook for further explanation.

# %%
mf.BrauerSIS(plot=True)
# Out:
#          days   susceptible      infected  recovered     total
# 0        0.00  99000.000000   1000.000000        0.0  100000.0
# 1        0.01  98998.025000   1001.975000        0.0  100000.0
# 2        0.02  98996.046149   1003.953851        0.0  100000.0
# 3        0.03  98994.063439   1005.936561        0.0  100000.0
# 4        0.04  98992.076864   1007.923136        0.0  100000.0
# ...       ...           ...           ...        ...       ...
# 36495  364.95  20000.000000  80000.000000        0.0  100000.0
# 36496  364.96  20000.000000  80000.000000        0.0  100000.0
# 36497  364.97  20000.000000  80000.000000        0.0  100000.0
# 36498  364.98  20000.000000  80000.000000        0.0  100000.0
# 36499  364.99  20000.000000  80000.000000        0.0  100000.0
#
# [36500 rows x 5 columns]

# %% [markdown]
# ### SIR model with birth and death
#
# Possible inputs: (Default values shown)
#
#     initial_population=100000
#     length_of_infection=20
#     avg_contacts_per_day=0.25
#     total_time=365
#     initial_percent_recovered=0.0
#     initial_percent_infected=1.0
#     fraction_recovered=1.0
#     deaths_per_100000_per_day=2.4
#     births_per_100000_per_day=3.3
#     xmin=0
#     xmax=365
#     ymin=0,
#     ymax=105000
#     plot=False
#     patameters=False
#
# The plot variable turns on and off the plot output. The parameters variable turns on and off a print message with the parameters. The xmin, xmax, ymin, and ymax values scale the plot. See Brauer SIR with birth and death notebook for further explanation.

# %%
mf.BrauerSIRbirthdeath(plot=True)
# Out:
#          days   susceptible     infected     recovered          total
# 0        0.00  99000.000000  1000.000000      0.000000  100000.000000
# 1        0.01  98997.534240  1001.974760      0.500000  100000.009000
# 2        0.02  98995.063655  1003.953358      1.000987  100000.018000
# 3        0.03  98992.588236  1005.935800      1.502964  100000.027000
# 4        0.04  98990.107974  1007.922095      2.005931  100000.036000
# ...       ...           ...          ...           ...            ...
# 36495  364.95   1650.995571     0.000000  98677.999419  100328.994990
# 36496  364.96   1651.028283     0.000000  98677.975736  100329.004019
# 36497  364.97   1651.060996     0.000000  98677.952053  100329.013049
# 36498  364.98   1651.093708     0.000000  98677.928370  100329.022078
# 36499  364.99   1651.126420     0.000000  98677.904688  100329.031108
#
# [36500 rows x 5 columns]

# %% [markdown]
# ### SIR model with birth, death and temporary immunity
#
# Possible inputs: (Default values shown)
#
#     initial_population=100000
#     length_of_infection=20
#     avg_contacts_per_day=0.25
#     total_time=365
#     initial_percent_recovered=0.0
#     initial_percent_infected=1.0
#     fraction_recovered=1.0
#     deaths_per_100000_per_day=2.4
#     births_per_100000_per_day=3.3
#     length_of_immunity=90
#     xmin=0
#     xmax=365
#     ymin=0,
#     ymax=105000
#     plot=False
#     patameters=False
#
# The plot variable turns on and off the plot output. The parameters variable turns on and off a print message with the parameters. The xmin, xmax, ymin, and ymax values scale the plot. See Brauer SIR with birth and death notebook for further explanation.

# %%
mf.BrauerSIRSbirthdeath(plot=True)
# Out:
#          days   susceptible      infected     recovered          total
# 0        0.00  99000.000000   1000.000000      0.000000  100000.000000
# 1        0.01  98997.534240   1001.974760      0.500000  100000.009000
# 2        0.02  98995.063711   1003.953358      1.000932  100000.018000
# 3        0.03  98992.588403   1005.935800      1.502797  100000.027000
# 4        0.04  98990.108308   1007.922095      2.005597  100000.036000
# ...       ...           ...           ...           ...            ...
# 36495  364.95  20072.858760  14632.058012  65624.078218  100328.994990
# 36496  364.96  20072.860013  14632.057074  65624.086933  100329.004019
# 36497  364.97  20072.861267  14632.056136  65624.095646  100329.013049
# 36498  364.98  20072.862522  14632.055198  65624.104358  100329.022078
# 36499  364.99  20072.863780  14632.054260  65624.113069  100329.031108
#
# [36500 rows x 5 columns]

# %% [markdown]
# ### Exploration

# %%
f = mf.BrauerSIRbirthdeath(total_time=500) - mf.BrauerSIR(total_time=500)
g = 200*(mf.BrauerSIRbirthdeath(total_time=500) - mf.BrauerSIR(total_time=500))/(mf.BrauerSIRbirthdeath(total_time=500)+mf.BrauerSIR(total_time=500))
h = mf.BrauerSIR(total_time=500)
k = mf.BrauerSIRbirthdeath(total_time=500)

mf.PlotSIR(t=h.days, S=g.susceptible, I=g.infected, R=g.recovered, N=g.total,
       title='Percent difference between models', legend_location='upper left',
           xlabel='days since 1 percent of population infected',
       ylabel='percent difference')

mf.PlotSIR(t=h.days, S=f.susceptible, I=f.infected, R=f.recovered, N=f.total,
          title='Difference between models', legend_location='upper left',
           xlabel= 'days since 1 percent of population infected',
          ylabel='population difference')

# %%
k.loc[k.infected==0]
# Out:
#          days  susceptible  infected     recovered          total
# 26652  266.52  1328.771888       0.0  98911.384014  100240.155903
# 26653  266.53  1328.804649       0.0  98911.360276  100240.164924
# 26654  266.54  1328.837409       0.0  98911.336537  100240.173946
# 26655  266.55  1328.870169       0.0  98911.312798  100240.182967
# 26656  266.56  1328.902930       0.0  98911.289059  100240.191989
# ...       ...          ...       ...           ...            ...
# 49995  499.95  2092.168753       0.0  98358.800044  100450.968797
# 49996  499.96  2092.201399       0.0  98358.776438  100450.977838
# 49997  499.97  2092.234046       0.0  98358.752832  100450.986878
# 49998  499.98  2092.266693       0.0  98358.729226  100450.995919
# 49999  499.99  2092.299340       0.0  98358.705620  100451.004960
#
# [23348 rows x 5 columns]

# %%
h.loc[h.infected==0]
# Out:
#          days  susceptible  infected     recovered         total
# 26324  263.24   689.168568       0.0  99309.832073  99999.000641
# 26325  263.25   689.168568       0.0  99309.832073  99999.000641
# 26326  263.26   689.168568       0.0  99309.832073  99999.000641
# 26327  263.27   689.168568       0.0  99309.832073  99999.000641
# 26328  263.28   689.168568       0.0  99309.832073  99999.000641
# ...       ...          ...       ...           ...           ...
# 49995  499.95   689.168568       0.0  99309.832073  99999.000641
# 49996  499.96   689.168568       0.0  99309.832073  99999.000641
# 49997  499.97   689.168568       0.0  99309.832073  99999.000641
# 49998  499.98   689.168568       0.0  99309.832073  99999.000641
# 49999  499.99   689.168568       0.0  99309.832073  99999.000641
#
# [23676 rows x 5 columns]

# %%
g[pd.isnull(g.infected)]
# Out:
#        days  susceptible  infected  recovered     total
# 26652   0.0    63.391694       NaN  -0.402024  0.240867
# 26653   0.0    63.393912       NaN  -0.402048  0.240876
# 26654   0.0    63.396130       NaN  -0.402072  0.240885
# 26655   0.0    63.398347       NaN  -0.402096  0.240894
# 26656   0.0    63.400565       NaN  -0.402120  0.240903
# ...     ...          ...       ...        ...       ...
# 49995   0.0   100.886734       NaN  -0.962249  0.450954
# 49996   0.0   100.887897       NaN  -0.962273  0.450963
# 49997   0.0   100.889060       NaN  -0.962297  0.450972
# 49998   0.0   100.890223       NaN  -0.962321  0.450981
# 49999   0.0   100.891387       NaN  -0.962345  0.450990
#
# [23348 rows x 5 columns]

# %%
g.infected = g.infected.replace(g.infected[26324:], 0.0)

# %%
g
# Out:
#        days  susceptible  infected     recovered     total
# 0       NaN     0.000000  0.000000           NaN  0.000000
# 1       0.0     0.000009 -0.000024  2.387424e-09  0.000009
# 2       0.0     0.000019 -0.000048 -2.397619e-05  0.000018
# 3       0.0     0.000028 -0.000072 -4.795264e-05  0.000027
# 4       0.0     0.000037 -0.000096 -7.192802e-05  0.000036
# ...     ...          ...       ...           ...       ...
# 49995   0.0   100.886734  0.000000 -9.622488e-01  0.450954
# 49996   0.0   100.887897  0.000000 -9.622728e-01  0.450963
# 49997   0.0   100.889060  0.000000 -9.622968e-01  0.450972
# 49998   0.0   100.890223  0.000000 -9.623208e-01  0.450981
# 49999   0.0   100.891387  0.000000 -9.623448e-01  0.450990
#
# [50000 rows x 5 columns]

# %%
mf.PlotSIR(t=h.days, S=g.susceptible, I=g.infected, R=g.recovered, N=g.total,
       title='Percent difference between models', legend_location='upper left',
           xlabel='days since 1 percent of population infected',
       ylabel='percent difference', plotname='SIRbdcomparisonpd.png',
          plotsave=True)

# %%
mf.PlotSIR(t=h.days, S=f.susceptible, I=f.infected, R=f.recovered, N=f.total,
          title='Difference between models', legend_location='upper left',
           xlabel= 'days since 1 percent of population infected',
          ylabel='population difference', plotname='SIRbdcomparisonad.png',
          plotsave=True)
