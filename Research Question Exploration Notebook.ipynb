# %% [markdown]
# # This notebook is for exploring research questions

# %% [markdown]
# ### Importing packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import scipy as sp
import pandas as pd
import Model_Functions as mf
import modifiedBrauerSIRSbd as mb

# %% [markdown]
# ### Basic SIR model
#
# Call function mf.BrauerSIR()
#
# Possible inputs: (Default values shown)
#
#     initial_population=100000
#     length_of_infection=20
#     avg_contacts_per_day=0.25
#     total_time=365
#     initial_percent_recovered=0.0
#     initial_percent_infected=1.0
#     plot=False
#     parameters=False
#
# The plot variable turns on and off the plot output. The parameters variable turns on and off a print message with the parameters. See Kermack-McKendrick SIR Model (Brauer 2008) notebook for further explanation.

# %%
mf.BrauerSIR(plot=True)
# Out:
#          days   susceptible     infected     recovered     total
# 0        0.00  99000.000000  1000.000000      0.000000  100000.0
# 1        0.01  98997.525000  1001.975000      0.500000  100000.0
# 2        0.02  98995.045174  1003.953839      1.000987  100000.0
# 3        0.03  98992.560512  1005.936523      1.502964  100000.0
# 4        0.04  98990.071007  1007.923061      2.005933  100000.0
# ...       ...           ...          ...           ...       ...
# 36495  364.95    689.168568     0.000000  99309.832073  100000.0
# 36496  364.96    689.168568     0.000000  99309.832073  100000.0
# 36497  364.97    689.168568     0.000000  99309.832073  100000.0
# 36498  364.98    689.168568     0.000000  99309.832073  100000.0
# 36499  364.99    689.168568     0.000000  99309.832073  100000.0
#
# [36500 rows x 5 columns]

# %% [markdown]
# ### Basic SEIR model
#
# Possible inputs: (Default values shown)
#
#     initial_population=100000
#     length_of_infection=20
#     length_of_exposure=5
#     avg_contacts_per_day=0.25
#     total_time=365
#     initial_percent_recovered=0.0
#     initial_percent_infected=1.0
#     initial_percent_exposed=0.0
#     plot=False
#     parameters=False
#
# The plot variable turns on and off the plot output. The parameters variable turns on and off a print message with the parameters. See Brauer 2008 SEIR model notebook for further explanation.

# %%
mf.BrauerSEIR(plot=True)
# Out:
#          days   susceptible   exposed     infected     recovered     total
# 0        0.00  99000.000000  0.000000  1000.000000      0.000000  100000.0
# 1        0.01  98997.525000  2.475000   999.500000      0.500000  100000.0
# 2        0.02  98995.051299  4.943751   999.005200      0.999750  100000.0
# 3        0.03  98992.578885  7.406277   998.515585      1.499253  100000.0
# 4        0.04  98990.107744  9.862606   998.031140      1.998510  100000.0
# ...       ...           ...       ...          ...           ...       ...
# 36495  364.95    689.582310  0.000000     0.000000  99305.422698  100000.0
# 36496  364.96    689.582310  0.000000     0.000000  99305.422698  100000.0
# 36497  364.97    689.582310  0.000000     0.000000  99305.422698  100000.0
# 36498  364.98    689.582310  0.000000     0.000000  99305.422698  100000.0
# 36499  364.99    689.582310  0.000000     0.000000  99305.422698  100000.0
#
# [36500 rows x 6 columns]

# %% [markdown]
# ### Basic SIS model
#
# Possible inputs: (Default values shown)
#
#     initial_population=100000
#     length_of_infection=20
#     avg_contacts_per_day=0.25
#     total_time=365
#     initial_percent_recovered=0.0
#     initial_percent_infected=1.0
#     fraction_recovered=1
#     plot=False
#     parameters=False
#
# The plot variable turns on and off the plot output. The parameters variable turns on and off a print message with the parameters. See Brauer 2008 SIS notebook for further explanation.

# %%
mf.BrauerSIS(plot=True)
# Out:
#          days   susceptible      infected  recovered     total
# 0        0.00  99000.000000   1000.000000        0.0  100000.0
# 1        0.01  98998.025000   1001.975000        0.0  100000.0
# 2        0.02  98996.046149   1003.953851        0.0  100000.0
# 3        0.03  98994.063439   1005.936561        0.0  100000.0
# 4        0.04  98992.076864   1007.923136        0.0  100000.0
# ...       ...           ...           ...        ...       ...
# 36495  364.95  20000.000000  80000.000000        0.0  100000.0
# 36496  364.96  20000.000000  80000.000000        0.0  100000.0
# 36497  364.97  20000.000000  80000.000000        0.0  100000.0
# 36498  364.98  20000.000000  80000.000000        0.0  100000.0
# 36499  364.99  20000.000000  80000.000000        0.0  100000.0
#
# [36500 rows x 5 columns]

# %% [markdown]
# ### SIR model with birth and death
#
# Possible inputs: (Default values shown)
#
#     initial_population=100000
#     length_of_infection=20
#     avg_contacts_per_day=0.25
#     total_time=365
#     initial_percent_recovered=0.0
#     initial_percent_infected=1.0
#     fraction_recovered=1.0
#     deaths_per_100000_per_day=2.4
#     births_per_100000_per_day=3.3
#     xmin=0
#     xmax=365
#     ymin=0,
#     ymax=105000
#     plot=False
#     patameters=False
#
# The plot variable turns on and off the plot output. The parameters variable turns on and off a print message with the parameters. The xmin, xmax, ymin, and ymax values scale the plot. See Brauer SIR with birth and death notebook for further explanation.

# %%
mf.BrauerSIRbirthdeath(plot=True)
# Out:
#          days   susceptible     infected     recovered          total
# 0        0.00  99000.000000  1000.000000      0.000000  100000.000000
# 1        0.01  98997.534240  1001.974760      0.500000  100000.009000
# 2        0.02  98995.063655  1003.953358      1.000987  100000.018000
# 3        0.03  98992.588236  1005.935800      1.502964  100000.027000
# 4        0.04  98990.107974  1007.922095      2.005931  100000.036000
# ...       ...           ...          ...           ...            ...
# 36495  364.95   1650.995571     0.000000  98677.002558  100328.994990
# 36496  364.96   1651.028283     0.000000  98676.978875  100329.004019
# 36497  364.97   1651.060996     0.000000  98676.955193  100329.013049
# 36498  364.98   1651.093708     0.000000  98676.931510  100329.022078
# 36499  364.99   1651.126420     0.000000  98676.907828  100329.031108
#
# [36500 rows x 5 columns]

# %% [markdown]
# ### SIR model with birth, death and temporary immunity
#
# Possible inputs: (Default values shown)
#
#     initial_population=100000
#     length_of_infection=20
#     avg_contacts_per_day=0.25
#     total_time=365
#     initial_percent_recovered=0.0
#     initial_percent_infected=1.0
#     fraction_recovered=1.0
#     deaths_per_100000_per_day=2.4
#     births_per_100000_per_day=3.3
#     length_of_immunity=90
#     xmin=0
#     xmax=365
#     ymin=0,
#     ymax=105000
#     plot=False
#     patameters=False
#
# The plot variable turns on and off the plot output. The parameters variable turns on and off a print message with the parameters. The xmin, xmax, ymin, and ymax values scale the plot. See Brauer SIR with birth and death notebook for further explanation.

# %%
mf.BrauerSIRSbirthdeath(plot=True)
# Out:
#          days   susceptible      infected     recovered          total
# 0        0.00  99000.000000   1000.000000      0.000000  100000.000000
# 1        0.01  98997.534240   1001.974760      0.500000  100000.009000
# 2        0.02  98995.063711   1003.953358      1.000932  100000.018000
# 3        0.03  98992.588403   1005.935800      1.502797  100000.027000
# 4        0.04  98990.108308   1007.922095      2.005597  100000.036000
# ...       ...           ...           ...           ...            ...
# 36495  364.95  20072.858760  14632.058012  65624.078218  100328.994990
# 36496  364.96  20072.860013  14632.057074  65624.086933  100329.004019
# 36497  364.97  20072.861267  14632.056136  65624.095646  100329.013049
# 36498  364.98  20072.862522  14632.055198  65624.104358  100329.022078
# 36499  364.99  20072.863780  14632.054260  65624.113069  100329.031108
#
# [36500 rows x 5 columns]

# %% [markdown]
# ### Exploration

# %%
f = mf.BrauerSIRbirthdeath(total_time=500
                           , initial_population=327600000) - mf.BrauerSIR(total_time=500,
                                                                         initial_population=327600000)
g = 200*(mf.BrauerSIRbirthdeath(total_time=500,
                                initial_population=327600000) - mf.BrauerSIR(
    total_time=500, initial_population=327600000))/(mf.BrauerSIRbirthdeath(
    total_time=500, initial_population=327600000)+mf.BrauerSIR(
    total_time=500, initial_population=327600000))
h = mf.BrauerSIR(total_time=500, initial_population=327600000, parameters=True)
k = mf.BrauerSIRbirthdeath(total_time=500, initial_population=327600000, parameters=True)

mf.PlotSIR(t=h.days, S=g.susceptible, I=g.infected, R=g.recovered, N=g.total,
       title='Percent difference between models', legend_location='upper left',
           xlabel='days since 1 percent of population infected',
       ylabel='percent difference')

mf.PlotSIR(t=h.days, S=f.susceptible, I=f.infected, R=f.recovered, N=f.total,
          title='Difference between models', legend_location='upper left',
           xlabel= 'days since 1 percent of population infected',
          ylabel='population difference')
# Out:
# Total time = 500 days
# Average contacts with an infective sufficient to transmit disease per day = 0.25 people
# Length of infection = 20 days
# Initial population = 327600000 people
# Initial percent recovered = 0.0%
# Initial percent infected = 1.0%
# R0 = 4.949999999999999
# Total time = 500 days
# Average contacts with an infective sufficient to transmit disease per day = 0.25 people
# Length of infection = 20 days
# Deaths per 100000 per day = 2.4 deaths
# Births per 100000 per day = 3.3 births
# Fraction of population who recover = 1.0
# Initial population = 327600000 people
# Initial percent recovered = 0.0%
# Initial percent infected = 1.0%
# R0 = 4.998

# %%
k.loc[k.infected==0]
# Out:
#          days   susceptible  infected     recovered         total
# 44246  442.46  6.238579e+06       0.0  3.226686e+08  3.289071e+08
# 44247  442.47  6.238686e+06       0.0  3.226685e+08  3.289072e+08
# 44248  442.48  6.238793e+06       0.0  3.226684e+08  3.289072e+08
# 44249  442.49  6.238900e+06       0.0  3.226683e+08  3.289072e+08
# 44250  442.50  6.239007e+06       0.0  3.226683e+08  3.289073e+08
# ...       ...           ...       ...           ...           ...
# 49995  499.95  6.853701e+06       0.0  3.222237e+08  3.290774e+08
# 49996  499.96  6.853808e+06       0.0  3.222236e+08  3.290774e+08
# 49997  499.97  6.853915e+06       0.0  3.222235e+08  3.290774e+08
# 49998  499.98  6.854022e+06       0.0  3.222234e+08  3.290775e+08
# 49999  499.99  6.854129e+06       0.0  3.222234e+08  3.290775e+08
#
# [5754 rows x 5 columns]

# %%
h.loc[h.infected==0]
# Out:
#          days   susceptible  infected     recovered        total
# 43087  430.87  2.257599e+06       0.0  3.253424e+08  327600000.0
# 43088  430.88  2.257599e+06       0.0  3.253424e+08  327600000.0
# 43089  430.89  2.257599e+06       0.0  3.253424e+08  327600000.0
# 43090  430.90  2.257599e+06       0.0  3.253424e+08  327600000.0
# 43091  430.91  2.257599e+06       0.0  3.253424e+08  327600000.0
# ...       ...           ...       ...           ...          ...
# 49995  499.95  2.257599e+06       0.0  3.253424e+08  327600000.0
# 49996  499.96  2.257599e+06       0.0  3.253424e+08  327600000.0
# 49997  499.97  2.257599e+06       0.0  3.253424e+08  327600000.0
# 49998  499.98  2.257599e+06       0.0  3.253424e+08  327600000.0
# 49999  499.99  2.257599e+06       0.0  3.253424e+08  327600000.0
#
# [6913 rows x 5 columns]

# %%
g[pd.isnull(g.infected)]
# Out:
#        days  susceptible  infected  recovered     total
# 44246   0.0    93.712235       NaN  -0.825242  0.398213
# 44247   0.0    93.713575       NaN  -0.825266  0.398222
# 44248   0.0    93.714914       NaN  -0.825290  0.398231
# 44249   0.0    93.716253       NaN  -0.825314  0.398240
# 44250   0.0    93.717592       NaN  -0.825338  0.398249
# ...     ...          ...       ...        ...       ...
# 49995   0.0   100.887935       NaN  -0.963215  0.449954
# 49996   0.0   100.889099       NaN  -0.963239  0.449963
# 49997   0.0   100.890262       NaN  -0.963263  0.449972
# 49998   0.0   100.891425       NaN  -0.963287  0.449981
# 49999   0.0   100.892589       NaN  -0.963311  0.449990
#
# [5754 rows x 5 columns]

# %%
g.infected = g.infected.replace(g.infected[43087:], 0.0)

# %%
g
# Out:
#        days  susceptible  infected  recovered     total
# 0       NaN     0.000000  0.000000        NaN  0.000000
# 1       0.0     0.000009 -0.000024   0.000000  0.000009
# 2       0.0     0.000019 -0.000048  -0.000024  0.000018
# 3       0.0     0.000028 -0.000072  -0.000048  0.000027
# 4       0.0     0.000037 -0.000096  -0.000072  0.000036
# ...     ...          ...       ...        ...       ...
# 49995   0.0   100.887935  0.000000  -0.963215  0.449954
# 49996   0.0   100.889099  0.000000  -0.963239  0.449963
# 49997   0.0   100.890262  0.000000  -0.963263  0.449972
# 49998   0.0   100.891425  0.000000  -0.963287  0.449981
# 49999   0.0   100.892589  0.000000  -0.963311  0.449990
#
# [50000 rows x 5 columns]

# %%
mf.PlotSIR(t=h.days, S=g.susceptible, I=g.infected, R=g.recovered, N=g.total,
       title='Percent difference between models', legend_location='upper left',
           xlabel='days since 1 percent of population infected',
       ylabel='percent difference', plotname='SIRbdcomparisonpd.png',
          plotsave=True)

# %%
mf.PlotSIR(t=h.days, S=f.susceptible, I=f.infected, R=f.recovered, N=f.total,
          title='Difference between models', legend_location='upper left',
           xlabel= 'days since 1 percent of population infected',
          ylabel='population difference', plotname='SIRbdcomparisonad.png',
          plotsave=True)

# %% [markdown]
# ### Work for presentation

# %% [markdown]
# Verification of birth/death rate model

# %%
a = mf.BrauerSIRbirthdeath(births_per_100000_per_day=0, deaths_per_100000_per_day=0,
                           total_time=500)-mf.BrauerSIR(total_time=500)
b = mf.BrauerSIR(total_time=500)
c = mf.BrauerSIRbirthdeath(births_per_100000_per_day=0, deaths_per_100000_per_day=0,
                           total_time=500)

# %%
mf.PlotSIR(t=b.days, S=a.susceptible, I=a.infected, R=a.recovered, N=a.total,
          title='Difference between models with birth/death rates = 0', legend_location='upper right',
           xlabel= 'days since 1 percent of population infected',
          ylabel='population difference', plotname='SIR-SIRndnb.png',
          plotsave=True)

# %%
d = mf.BrauerSIRbirthdeath(births_per_100000_per_day=0, deaths_per_100000_per_day=100000,
                          total_time=3, dt=1)
# Out:
# /Users/jsimpson/Documents/Linfield/Summer_Research_2020/CODESIR/Model_Functions.py:283: RuntimeWarning: divide by zero encountered in double_scalars
#   dSdt=nu*N[j]-lmbda/N[j]*S[j]*I[j]-mu*S[j]
# /Users/jsimpson/Documents/Linfield/Summer_Research_2020/CODESIR/Model_Functions.py:284: RuntimeWarning: divide by zero encountered in double_scalars
#   dIdt=lmbda/N[j]*S[j]*I[j]-mu*I[j]-alpha*I[j]

# %%
mf.PlotSIR(t=d.days, S=d.susceptible, I=d.infected, R=d.recovered, N=d.total,
          title='SIR model with death rate = 100%, dt=1', legend_location='upper right',
           xlabel= 'days since 1 percent of population infected',
          ylabel='population', plotname='SIRfulldeathdt=1.png',
          plotsave=True)

# %%
e = mf.BrauerSIRbirthdeath(births_per_100000_per_day=0, deaths_per_100000_per_day=100000,
                          total_time=3, dt=0.01)

# %%
mf.PlotSIR(t=e.days, S=e.susceptible, I=e.infected, R=e.recovered, N=e.total,
          title='SIR model with death rate = 100%, dt=0.01', legend_location='upper right',
           xlabel= 'days since 1 percent of population infected',
          ylabel='population', plotname='SIRfulldeathdt=0.01.png',
          plotsave=True)

# %% [markdown]
# Oregon State comparison

# %%
f = mf.BrauerSIRbirthdeath(
    total_time=500, births_per_100000_per_day=2.8,
    initial_population=4182000) - mf.BrauerSIR(total_time=500, initial_population=4182000)
g = 200*(mf.BrauerSIRbirthdeath(
    total_time=500, births_per_100000_per_day=2.8,
    initial_population=4182000) - mf.BrauerSIR(
    total_time=500, initial_population=4182000))/(mf.BrauerSIRbirthdeath(
    total_time=500, births_per_100000_per_day=2.8, initial_population=4182000)+mf.BrauerSIR(
    total_time=500, initial_population=4182000))
h = mf.BrauerSIR(total_time=500, initial_population=4182000)
i = mf.BrauerSIRbirthdeath(total_time=500, births_per_100000_per_day=2.8, initial_population=4182000)

mf.PlotSIR(t=h.days, S=g.susceptible, I=g.infected, R=g.recovered, N=g.total,
       title='Percent difference between models', legend_location='upper left',
           xlabel='days since 1 percent of population infected',
       ylabel='percent difference')

mf.PlotSIR(t=h.days, S=f.susceptible, I=f.infected, R=f.recovered, N=f.total,
          title='Difference between models', legend_location='upper left',
           xlabel= 'days since 1 percent of population infected',
          ylabel='population difference')

# %%
h.loc[h.infected==0]
# Out:
#          days   susceptible  infected     recovered      total
# 34056  340.56  28819.573666       0.0  4.153179e+06  4182000.0
# 34057  340.57  28819.573666       0.0  4.153179e+06  4182000.0
# 34058  340.58  28819.573666       0.0  4.153179e+06  4182000.0
# 34059  340.59  28819.573666       0.0  4.153179e+06  4182000.0
# 34060  340.60  28819.573666       0.0  4.153179e+06  4182000.0
# ...       ...           ...       ...           ...        ...
# 49995  499.95  28819.573666       0.0  4.153179e+06  4182000.0
# 49996  499.96  28819.573666       0.0  4.153179e+06  4182000.0
# 49997  499.97  28819.573666       0.0  4.153179e+06  4182000.0
# 49998  499.98  28819.573666       0.0  4.153179e+06  4182000.0
# 49999  499.99  28819.573666       0.0  4.153179e+06  4182000.0
#
# [15944 rows x 5 columns]

# %%
i.loc[i.infected==0]
# Out:
#          days   susceptible  infected     recovered         total
# 34595  345.95  60675.588236       0.0  4.127114e+06  4.187791e+06
# 34596  345.96  60676.746255       0.0  4.127113e+06  4.187791e+06
# 34597  345.97  60677.904274       0.0  4.127112e+06  4.187791e+06
# 34598  345.98  60679.062293       0.0  4.127111e+06  4.187792e+06
# 34599  345.99  60680.220312       0.0  4.127111e+06  4.187792e+06
# ...       ...           ...       ...           ...           ...
# 49995  499.95  78481.728417       0.0  4.111889e+06  4.190372e+06
# 49996  499.96  78482.882886       0.0  4.111888e+06  4.190372e+06
# 49997  499.97  78484.037354       0.0  4.111887e+06  4.190372e+06
# 49998  499.98  78485.191822       0.0  4.111886e+06  4.190372e+06
# 49999  499.99  78486.346289       0.0  4.111885e+06  4.190372e+06
#
# [15405 rows x 5 columns]

# %%
g.infected = g.infected.replace(g.infected[34056:], 0.0)

# %%
mf.PlotSIR(t=h.days, S=g.susceptible, I=g.infected, R=g.recovered, N=g.total,
       title='Percent difference between models', legend_location='upper left',
           xlabel='days since 1 percent of population infected',
       ylabel='percent difference', plotname='SIRbdcomparisonpdoregon.png',
          plotsave=True)

# %%
mf.PlotSIR(t=h.days, S=f.susceptible, I=f.infected, R=f.recovered, N=f.total,
          title='Difference between models', legend_location='upper left',
           xlabel= 'days since 1 percent of population infected',
          ylabel='population difference', plotname='SIRbdcomparisonadoregon.png',
          plotsave=True)

# %% [markdown]
# Comparison of different birth/death rates

# %%
a = mf.BrauerSIRbirthdeath(total_time=500, births_per_100000_per_day=0,
                       deaths_per_100000_per_day=0, xmax=500)

# %%
b = mf.BrauerSIRbirthdeath(total_time=500, births_per_100000_per_day=0,
                       deaths_per_100000_per_day=2, xmax=500)

# %%
c = mf.BrauerSIRbirthdeath(total_time=500, births_per_100000_per_day=0,
                       deaths_per_100000_per_day=5, xmax=500)

# %%
d = mf.BrauerSIRbirthdeath(total_time=500, births_per_100000_per_day=5,
                       deaths_per_100000_per_day=0, xmax=500)

# %%
e = mf.BrauerSIRbirthdeath(total_time=500, births_per_100000_per_day=5,
                       deaths_per_100000_per_day=2, xmax=500)

# %%
f = mf.BrauerSIRbirthdeath(total_time=500, births_per_100000_per_day=5,
                       deaths_per_100000_per_day=5, xmax=500)

# %%
g = mf.BrauerSIRbirthdeath(total_time=500, births_per_100000_per_day=15,
                       deaths_per_100000_per_day=0, xmax=500)

# %%
h = mf.BrauerSIRbirthdeath(total_time=500, births_per_100000_per_day=15,
                       deaths_per_100000_per_day=2, xmax=500)

# %%
i = mf.BrauerSIRbirthdeath(total_time=500, births_per_100000_per_day=15,
                       deaths_per_100000_per_day=5, xmax=500)

# %%
ab = b-a
ac = c-a
ad = d-a
ae = e-a
af = f-a
ag = g-a
ah = h-a
ai = i-a

# %%
mf.PlotSIR(t=a.days, S=a.susceptible, I=a.infected, R=a.recovered, N=a.total,
          title='SIR model with R0=5', legend_location='right',
           xlabel= 'days since 1 percent of population infected',
          ylabel='population', plotname='SIRbdcomparisonb0d0.png',
          plotsave=True)
mf.PlotSIR(t=a.days, S=ab.susceptible, I=ab.infected, R=ab.recovered, N=ab.total,
          title='Difference between SIR and SIRb0d2, R0=5', legend_location='lower left',
           xlabel= 'days since 1 percent of population infected',
          ylabel='population difference', plotname='SIRbdcomparisonb0d2.png',
          plotsave=True)
mf.PlotSIR(t=a.days, S=ac.susceptible, I=ac.infected, R=ac.recovered, N=ac.total,
          title='Difference between SIR and SIRb0d5, R0=5', legend_location='lower left',
           xlabel= 'days since 1 percent of population infected',
          ylabel='population difference', plotname='SIRbdcomparisonb0d5.png',
          plotsave=True)
mf.PlotSIR(t=a.days, S=ad.susceptible, I=ad.infected, R=ad.recovered, N=ad.total,
          title='Difference between SIR and SIRb5d0, R0=5', legend_location='upper left',
           xlabel= 'days since 1 percent of population infected',
          ylabel='population difference', plotname='SIRbdcomparisonb5d0.png',
          plotsave=True)
mf.PlotSIR(t=a.days, S=ae.susceptible, I=ae.infected, R=ae.recovered, N=ae.total,
          title='Difference between SIR and SIRb5d2, R0=5', legend_location='upper left',
           xlabel= 'days since 1 percent of population infected',
          ylabel='population difference', plotname='SIRbdcomparisonb5d2.png',
          plotsave=True)
mf.PlotSIR(t=a.days, S=af.susceptible, I=af.infected, R=af.recovered, N=af.total,
          title='Difference between SIR and SIRb5d5, R0=5', legend_location='upper left',
           xlabel= 'days since 1 percent of population infected',
          ylabel='population difference', plotname='SIRbdcomparisonb5d5.png',
          plotsave=True)
mf.PlotSIR(t=a.days, S=ag.susceptible, I=ag.infected, R=ag.recovered, N=ag.total,
          title='Difference between SIR and SIRb15d0, R0=5', legend_location='upper left',
           xlabel= 'days since 1 percent of population infected',
          ylabel='population difference', plotname='SIRbdcomparisonb15d0.png',
          plotsave=True)
mf.PlotSIR(t=a.days, S=ah.susceptible, I=ah.infected, R=ah.recovered, N=ah.total,
          title='Difference between SIR and SIRb15d2, R0=5', legend_location='upper left',
           xlabel= 'days since 1 percent of population infected',
          ylabel='population difference', plotname='SIRbdcomparisonb15d2.png',
          plotsave=True)
mf.PlotSIR(t=a.days, S=ai.susceptible, I=ai.infected, R=ai.recovered, N=ai.total,
          title='Difference between SIR and SIRb15d5, R0=5', legend_location='upper left',
           xlabel= 'days since 1 percent of population infected',
          ylabel='population difference', plotname='SIRbdcomparisonb15d5.png',
          plotsave=True)

# %% [markdown]
# Verification of immunity loss parameter

# %%
a = mf.BrauerSIRSbirthdeath(births_per_100000_per_day=0, deaths_per_100000_per_day=0,
                           total_time=500, length_of_immunity=1000000)-mf.BrauerSIR(total_time=500)
b = mf.BrauerSIR(total_time=500)
c = mf.BrauerSIRSbirthdeath(births_per_100000_per_day=0, deaths_per_100000_per_day=0,
                           total_time=500, length_of_immunity=1000000)

# %%
mf.PlotSIR(t=b.days, S=a.susceptible, I=a.infected, R=a.recovered, N=a.total,
          title='Difference between models with birth/death rates = 0 \n length of immunity=1,000,000',
           legend_location='upper right',
           xlabel= 'days since 1 percent of population infected',
          ylabel='population difference', plotname='SIR-SIRSndnb1E6.png',
          plotsave=True)

# %%
a = mf.BrauerSIRSbirthdeath(births_per_100000_per_day=0, deaths_per_100000_per_day=0,
                           total_time=500, length_of_immunity=1000000000)-mf.BrauerSIR(total_time=500)
b = mf.BrauerSIR(total_time=500)
c = mf.BrauerSIRSbirthdeath(births_per_100000_per_day=0, deaths_per_100000_per_day=0,
                           total_time=500, length_of_immunity=1000000000)

# %%
mf.PlotSIR(t=b.days, S=a.susceptible, I=a.infected, R=a.recovered, N=a.total,
          title='Difference between models with birth/death rates = 0 \n length of immunity=1,000,000,000',
           legend_location='upper right',
           xlabel= 'days since 1 percent of population infected',
          ylabel='population difference', plotname='SIR-SIRSndnb1E9.png',
          plotsave=True)

# %%
a = mf.BrauerSIRSbirthdeath(births_per_100000_per_day=0, deaths_per_100000_per_day=0,
                           total_time=500, length_of_immunity=0.01)-mf.BrauerSIS(total_time=500)
b = mf.BrauerSIS(total_time=500)
c = mf.BrauerSIRSbirthdeath(births_per_100000_per_day=0, deaths_per_100000_per_day=0,
                           total_time=500, length_of_immunity=0.01)

mf.PlotSIR(t=b.days, S=a.susceptible, I=a.infected, R=a.recovered, N=a.total,
          title='Difference between models with birth/death rates = 0 \n length of immunity=0.01',
           legend_location='upper right',
           xlabel= 'days since 1 percent of population infected',
          ylabel='population difference', plotname='SIS-SIRSndnb1E-2.png',
          plotsave=True)

# %%
a = mf.BrauerSIRSbirthdeath(births_per_100000_per_day=0, deaths_per_100000_per_day=0,
                           total_time=500, length_of_immunity=0.001, dt=0.001)-mf.BrauerSIS(
    total_time=500, dt=0.001)
b = mf.BrauerSIS(total_time=500, dt=0.001)
c = mf.BrauerSIRSbirthdeath(births_per_100000_per_day=0, deaths_per_100000_per_day=0,
                           total_time=500, length_of_immunity=0.001, dt=0.001)

mf.PlotSIR(t=b.days, S=a.susceptible, I=a.infected, R=a.recovered, N=a.total,
          title='Difference between models with birth/death rates = 0 \n length of immunity=0.001',
           legend_location='upper right',
           xlabel= 'days since 1 percent of population infected',
          ylabel='population difference', plotname='SIS-SIRSndnb1E-3.png',
          plotsave=True)

# %%
a = mf.BrauerSIRSbirthdeath(births_per_100000_per_day=0, deaths_per_100000_per_day=0,
                           total_time=500, length_of_immunity=0.0001, dt=0.0001)-mf.BrauerSIS(
    total_time=500, dt=0.0001)
b = mf.BrauerSIS(total_time=500, dt=0.0001)
c = mf.BrauerSIRSbirthdeath(births_per_100000_per_day=0, deaths_per_100000_per_day=0,
                           total_time=500, length_of_immunity=0.0001, dt=0.0001)

mf.PlotSIR(t=b.days, S=a.susceptible, I=a.infected, R=a.recovered, N=a.total,
          title='Difference between models with birth/death rates = 0 \n length of immunity=0.0001',
           legend_location='upper right',
           xlabel= 'days since 1 percent of population infected',
          ylabel='population difference', plotname='SIS-SIRSndnb1E-4.png',
          plotsave=True)

# %%
a = mf.BrauerSIRSbirthdeath(births_per_100000_per_day=5, deaths_per_100000_per_day=5,
                           total_time=500, length_of_immunity=1000000)-mf.BrauerSIRbirthdeath(
    births_per_100000_per_day=5, deaths_per_100000_per_day=5,
                           total_time=500,)
b = mf.BrauerSIS(total_time=500)
c = mf.BrauerSIRSbirthdeath(births_per_100000_per_day=5, deaths_per_100000_per_day=5,
                           total_time=500, length_of_immunity=1000000)

mf.PlotSIR(t=b.days, S=a.susceptible, I=a.infected, R=a.recovered, N=a.total,
          title='Difference between models with birth/death rates = 5 \n length of immunity=1,000,000',
           legend_location='upper right',
           xlabel= 'days since 1 percent of population infected',
          ylabel='population difference', plotname='SIRd5b5-SIRSd5b51E6.png',
          plotsave=True)

# %%
a = mf.BrauerSIRSbirthdeath(births_per_100000_per_day=5, deaths_per_100000_per_day=5,
                           total_time=500, length_of_immunity=1000000000)-mf.BrauerSIRbirthdeath(
    births_per_100000_per_day=5, deaths_per_100000_per_day=5,
                           total_time=500,)
b = mf.BrauerSIS(total_time=500)
c = mf.BrauerSIRSbirthdeath(births_per_100000_per_day=5, deaths_per_100000_per_day=5,
                           total_time=500, length_of_immunity=1000000000)

mf.PlotSIR(t=b.days, S=a.susceptible, I=a.infected, R=a.recovered, N=a.total,
          title='Difference between models with birth/death rates = 5 \n length of immunity=1,000,000,000',
           legend_location='upper right',
           xlabel= 'days since 1 percent of population infected',
          ylabel='population difference', plotname='SIRd5b5-SIRSd5b51E9.png',
          plotsave=True)

# %%
a = mf.BrauerSIRSbirthdeath(births_per_100000_per_day=5, deaths_per_100000_per_day=5,
                           total_time=500, length_of_immunity=10000)-mf.BrauerSIRbirthdeath(
    births_per_100000_per_day=5, deaths_per_100000_per_day=5,
                           total_time=500,)
b = mf.BrauerSIS(total_time=500)
c = mf.BrauerSIRSbirthdeath(births_per_100000_per_day=5, deaths_per_100000_per_day=5,
                           total_time=500, length_of_immunity=10000)

mf.PlotSIR(t=b.days, S=a.susceptible, I=a.infected, R=a.recovered, N=a.total,
          title='Difference between models with birth/death rates = 5 \n length of immunity=10,000',
           legend_location='upper left',
           xlabel= 'days since 1 percent of population infected',
          ylabel='population difference', plotname='SIRd5b5-SIRSd5b51E4.png',
          plotsave=True)

# %%
a = mf.BrauerSIRSbirthdeath(births_per_100000_per_day=5, deaths_per_100000_per_day=5,
                           total_time=500, length_of_immunity=5000)-mf.BrauerSIRbirthdeath(
    births_per_100000_per_day=5, deaths_per_100000_per_day=5,
                           total_time=500,)
b = mf.BrauerSIS(total_time=500)
c = mf.BrauerSIRSbirthdeath(births_per_100000_per_day=5, deaths_per_100000_per_day=5,
                           total_time=500, length_of_immunity=5000)

mf.PlotSIR(t=b.days, S=a.susceptible, I=a.infected, R=a.recovered, N=a.total,
          title='Difference between models with birth/death rates = 5 \n length of immunity=5,000',
           legend_location='upper left',
           xlabel= 'days since 1 percent of population infected',
          ylabel='population difference', plotname='SIRd5b5-SIRSd5b55E3.png',
          plotsave=True)

# %%
a = mf.BrauerSIRSbirthdeath(births_per_100000_per_day=5, deaths_per_100000_per_day=5,
                           total_time=500, length_of_immunity=1000)-mf.BrauerSIRbirthdeath(
    births_per_100000_per_day=5, deaths_per_100000_per_day=5,
                           total_time=500,)
b = mf.BrauerSIS(total_time=500)
c = mf.BrauerSIRSbirthdeath(births_per_100000_per_day=5, deaths_per_100000_per_day=5,
                           total_time=500, length_of_immunity=1000)

mf.PlotSIR(t=b.days, S=a.susceptible, I=a.infected, R=a.recovered, N=a.total,
          title='Difference between models with birth/death rates = 5 \n length of immunity=1,000',
           legend_location='upper left',
           xlabel= 'days since 1 percent of population infected',
          ylabel='population difference', plotname='SIRd5b5-SIRSd5b51E3.png',
          plotsave=True)

# %%
a = mf.BrauerSIRSbirthdeath(births_per_100000_per_day=5, deaths_per_100000_per_day=5,
                           total_time=500, length_of_immunity=500)-mf.BrauerSIRbirthdeath(
    births_per_100000_per_day=5, deaths_per_100000_per_day=5,
                           total_time=500,)
b = mf.BrauerSIS(total_time=500)
c = mf.BrauerSIRSbirthdeath(births_per_100000_per_day=5, deaths_per_100000_per_day=5,
                           total_time=500, length_of_immunity=500)

mf.PlotSIR(t=b.days, S=a.susceptible, I=a.infected, R=a.recovered, N=a.total,
          title='Difference between models with birth/death rates = 5 \n length of immunity=500',
           legend_location='upper left',
           xlabel= 'days since 1 percent of population infected',
          ylabel='population difference', plotname='SIRd5b5-SIRSd5b55E2.png',
          plotsave=True)

# %% [markdown]
# ### Model Exploration

# %%
for i in [0, 1, 2, 3]:
    if i == 0:
        days=1
    else:
        days=(365*i)
    a = mf.BrauerSIRSbirthdeath(length_of_immunity=days, total_time=1500,
        initial_population=327200000)
    mf.PlotSIR(t=a.days, S=a.susceptible, I=a.infected, R=a.recovered, N=a.total,
              title= 'SIR model with birth, death and immunity for ' + str(days)
               + ' days \n R0=5', xlabel= 'days since 1.0 percent of population infected',
              ylabel = 'population', plotname= 'SIRbdUSAR05im' + str(days) + '.png', plotsave=True)

# %%
for i in [0, 1, 2, 3]:
    if i == 0:
        days=1
    else:
        days=(365*i)
    a = mf.BrauerSIRSbirthdeath(length_of_immunity=days, total_time=1500,
        initial_population=327200000, length_of_infection=10,
                                avg_contacts_per_day=0.2)
    mf.PlotSIR(t=a.days, S=a.susceptible, I=a.infected, R=a.recovered, N=a.total,
              title= 'SIR model with birth, death and immunity for ' + str(days)
               + ' days \n R0=2.0', xlabel= 'days since 1.0 percent of population infected',
              ylabel = 'population', plotname= 'SIRbdUSAR02im' + str(days) + '.png', plotsave=True)

# %% [markdown]
# ### Adding in a stochastic component to termination cut-off

# %%
mb.modifiedBrauerSIRSbd()
# Out:
# 0.7188507964809223
#          days   susceptible      infected     recovered          total
# 0        0.00  99000.000000   1000.000000      0.000000  100000.000000
# 1        0.01  98997.534240   1001.974760      0.500000  100000.009000
# 2        0.02  98995.063711   1003.953358      1.000932  100000.018000
# 3        0.03  98992.588403   1005.935800      1.502797  100000.027000
# 4        0.04  98990.108308   1007.922095      2.005597  100000.036000
# ...       ...           ...           ...           ...            ...
# 36495  364.95  20072.858760  14632.058012  65624.078218  100328.994990
# 36496  364.96  20072.860013  14632.057074  65624.086933  100329.004019
# 36497  364.97  20072.861267  14632.056136  65624.095646  100329.013049
# 36498  364.98  20072.862522  14632.055198  65624.104358  100329.022078
# 36499  364.99  20072.863780  14632.054260  65624.113069  100329.031108
#
# [36500 rows x 5 columns]

# %%
a = np.zeros(100)
for i in range(100):
    a[i] = mb.modifiedBrauerSIRSbd()
    
#for j in range(100):
 #   sus = a[j].suscetible
# Out:
# 0.5363582750091802
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a number, not 'DataFrame'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-48952c563054> in <module>
#       1 a = np.zeros(100)
#       2 for i in range(100):
# ----> 3     a[i] = mb.modifiedBrauerSIRSbd()
#       4
#       5 #for j in range(100):
#
# ValueError: setting an array element with a sequence.
